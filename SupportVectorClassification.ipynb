# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreenithya1609/DL-class/blob/main/SupportVectorClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
d=pd.read_csv('/content/drive/MyDrive/credit_risk_dataset.csv/iris - iris.csv')
d.head()
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm        class
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
#image
import matplotlib.image as mpimg
img=mpimg.imread('/content/drive/MyDrive/credit_risk_dataset.csv/iris_types.jpg')
img
# Out:
# array([[[119, 161, 137],
#         [118, 160, 136],
#         [116, 158, 134],
#         ...,
#         [ 29,  35,  47],
#         [ 22,  30,  43],
#         [ 18,  27,  42]],
#
#        [[116, 159, 132],
#         [118, 161, 134],
#         [117, 160, 133],
#         ...,
#         [ 37,  44,  54],
#         [ 24,  32,  45],
#         [ 23,  33,  45]],
#
#        [[120, 160, 133],
#         [119, 159, 132],
#         [119, 159, 132],
#         ...,
#         [ 45,  49,  58],
#         [ 31,  37,  49],
#         [ 27,  35,  46]],
#
#        ...,
#
#        [[ 48,  98,  60],
#         [ 52, 100,  60],
#         [ 54, 100,  61],
#         ...,
#         [ 79,  90,  92],
#         [ 47,  58,  62],
#         [ 30,  41,  45]],
#
#        [[ 50, 101,  60],
#         [ 52, 103,  62],
#         [ 54, 102,  62],
#         ...,
#         [ 64,  75,  79],
#         [ 32,  43,  49],
#         [ 25,  35,  44]],
#
#        [[ 52, 103,  60],
#         [ 52, 103,  60],
#         [ 52, 103,  62],
# ...

# %%
#finding the nullvalues
d.isna().sum()
# Out:
# sepal length in cm    0
# sepal width in cm     0
# petal length in cm    0
# petal width in cm     0
# class                 0
# dtype: int64

# %%
#image
plt.figure(figsize=(10,10))
plt.axis("off")
plt.imshow(img,cmap="gray")

# %%
#Splitting the dataset
x=d[['petal length in cm','petal width in cm']].values
y=d['class'].values

# %%
#Training and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
#fitting the Classifier
from sklearn.svm import SVC
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
#prediction
y_pred=svc.predict(x_test)
print(y_pred)
# Out:
# ['Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-virginica'
#  'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-versicolor' 'Iris-virginica' 'Iris-virginica' 'Iris-setosa'
#  'Iris-virginica' 'Iris-versicolor' 'Iris-setosa' 'Iris-setosa'
#  'Iris-virginica' 'Iris-virginica' 'Iris-setosa' 'Iris-setosa'
#  'Iris-virginica' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-setosa']
